# %% [markdown]
# # Workshop 1
#
# This notebook will cover the following topics:
#
# 1. Basic Input/Output and formatting
# 2. Decision Structure and Boolean Logic
# 3. Basic Loop Structures
# 4. Data Structures

# %% [markdown]
# ## 1.1 Basic Input/Output and formatting (Follow):
#
# **Learning Objectives:**
#
#     1. Perform basic input and output for a user
#     2. Format input and output
#     3. Perform basic math on input and output
#     4. Understand different datatypes

# %%
#Add comments below 

print ("This is a print statement")
print ("Try printing some different things including num8er5")

input_string = input("Enter a short string here:")

print ("The string you input is: ", input_string)

float_number = 2
print("This will print a float number with 2 decimal places: ", format(float_number, '.2f'))

num1 = 5
num2 = 10
print(f"This will multiply {num1} times {num2} and display the result: ", num1*num2)

# %% [markdown]
# ## 1.1 Basic Input/Output and formatting (Group):
#
# 1. Create a small program that will take a celcius temperature from the user and convert it to fahrenheit
# 2. Print the output result to 3 decimal places
# 3. Print a degree sign after the output
# 4. Try to figure out how to create the program in the fewest lines possible
#
# Fahrenheit = (9/5)(Degrees Celcius) + 32

# %%
# Formula to convert celc to fahrenheit = ((9/5)* celc) + 32
celc = input("Enter the current degrees in celcius: ")

# %%
F_degrees = ((9/5)* int(celc)) + 32
print("Current Fahrenheit Temp: ", format(F_degrees, '.3f'), u'\N{DEGREE SIGN}')

# %% [markdown]
# ## 1.2 Decision Structure and Boolean Logic (Follow):
#
# **Learning Objectives:**
#
#     1. Understand boolean logic and logical operators
#     2. Understand If/Else statements and program flow

# %%
#Add comments below 

day = int(input('Enter a number (1-7) for the day of the week: '))

if day == 1:
    print('Monday')
elif day == 2:
    print('Tuesday')
elif day == 3:
    print('Wednesday')
elif day == 4:
    print ('Thursday')
elif day == 5:
    print ('Friday')
elif day == 6:
    print ('Saturday')
elif day == 7:
    print ('Sunday')
else:
    print ('Error: Please enter a number in the range 1-7.')

# %% [markdown]
# After running this program, think about and answer these questions:
#
# 1. What is the program doing?
#
# program is using if else statements for evaluations of the input against predetermined values is true.
# 2. Does every line in the code execute, explain?
#
# No... goes line by line until True, then ignores the remaining conditions.
# 3. Could you find a way to break it?
#
# Entering a letter, or symbol, as there is no validation of inputs.

# %%
#Add comments below 

RED = 'red'
BLUE = 'blue'
YELLOW = 'yellow'

color1 = input('Enter the first primary color in lower case letters: ')

color2 = input('Enter the second primary color in lower case letters: ')

# check for invalid input of variable color1
if color1 != RED and color1 != BLUE and color1 != YELLOW:
    print('Error: The first color you entered is invalid.')

# check for invalid input of variable color2
elif color2 != RED and color2 != BLUE and color2 != YELLOW:
    print('Error: The second color you entered is invalid.')

# check for same color and output error.
elif color1 == color2:
    print('Error: The two colors you entered are the same.')

else:
    #the following conditions are results of mixing colors
    if color1 == RED:
        if color2 == BLUE:
            print('purple')
        else: #color 2 must be yellow
            print('orange')

    elif color1 == BLUE:
        if color2 == RED:
            print('purple')
        else: # color2 must be yellow
            print('green')

    else: # color1 option is only yellow at this point
        if color2 == RED:
            print('orange')
        else: # color2 must be blue 
            print('green')

# %% [markdown]
# After running this program, think about and answer these questions:
#
# 1. What is the program doing?
#
# Program is asking primary colors, if none are supplied errors will be posted.
# the evaluations are successful only if all values are true.
#
# 2. Does every line in the code execute, explain?
#
# not every line is executed as the evaluations of true/false statements are being tested.
#
# 3. Could you find a way to break it?
#
# breaking the code can be accomplished by entering UPPER CASE values, or mixed case values.
#
# 4. Replace the 'ands' with 'ors' and discuss how the program executes now.
#
# Replacing ands with ors, results in values being evaluated and returns true if only one VALUE is TRUE.
# This results in error prone code, and the evaluations are improperly formatted.

# %% [markdown]
# ## 1.2 Decision Structure and Boolean Logic (Group):
#
# Develop a program that will do the following:
#
# 1. Take input from the user for length and width for two different sets of numbers. Fours total inputs.
# 2. Multiply the length and width together and find the area for the two different sets of numbers.
# 3. Compare the areas and print which one is larger.
# 4. Be sure to handle non-numeric inputs.

# %%
#4 create condition to handle non-numberic inputs
while True:
    try:
    #1. get lengths and widths for two different sets of inputs.  4 total.
        length = int(input("Input length: "))
        length_b = int(input("Input another length"))
        width = int(input("Input width: "))
        width_b = int(input("Input another width: "))
    except:
        print("input numbers only - try again")
        continue
     #check for valid inputs of numbers only - integers
    if isinstance(length, int) and isinstance(length_b, int) and isinstance(width, int) and isinstance(width_b, int):
        #if all integers are present and true break out of the while loop
        break
    else: #else loop get the varibles again, prompt user
        print("input numbers only - try again")        
        
#2. calculate areas
area_1 = length * width
area_2 = length_b * width_b

#3. find which is bigger and output results
if area_1 > area_2:
    print("Area 1 is larger")
elif area_1 < area_2:
    print("Area_2 is larger")
else:
    print("Equal areas of both sets");

# %%
''' group shared code 
while True:
    try:
        length_1, length_2 = [int(x) for x in input("Enter two length values, separated by a comma: ").split(',')]
        width_1, width_2 = [int(x) for x in input("Enter two width values, separated by a comma: ").split(',')]
    except:
        print('Enter integer values only')
        continue
    # is there a better way to check multiple variables for type?
    if isinstance(length_1, int) and isinstance(length_2, int) and isinstance(width_1, int) \
        and isinstance(width_2, int):
            break
    else:
        print("Enter integer values only")

total_1 = length_1 * width_1
total_2 = length_2 * width_2

if total_1 > total_2:
    print('The first set of numbers has the greater area')
elif total_2 > total_1:
    print('The second set of numbers has the greater area')
else:
    print('The areas for both sets of inputs are equal')
'''

# %% [markdown]
# ## 1.3 Basic loop structures (Follow):
#
# **Learning Objectives:**
#
#
#     1. Understanding repetative structures
#     2. Understanding while loops
#     3. Understanding for loops
#     4. Nested loops and order N run time

# %%
#Add comments below

number = 1.0    
total = 0.0
# while condition is true... repeat the loop and calculate the input to the total
while number > 0:
    # a negative number will break this while loop, tell the user how to quit
    # all entries will be accepted as float integers
    number = float(input('Enter a positive number (negative to quit): '))

    if number > 0:
        total = total + number
#print the output with 2 decimal values
print (f'Total = {total:.2f}')

# %% [markdown]
# After running this program, think about and answer these questions:
#
# 1. What is the program doing?
#
# Runs inputs till a negative number is entered, then total is provided.
#
# 2. How many time does each line in the code execute, explain?
#
# The execution of the while loop will continue as long as there is a valid number, but it will execute in whole, once, as long as the input is valid (int > 0).
#
# 3. Could you find a way to break it?
#
# yes... enter 2 dots or a symbol, or "0" will break the code.
#
# 4. Try to rewrite the program using a for loop.
#
# number = 1.0
# total = 0.0
# for x in range(1,10): # x is never changed so loop will cycle without end
#     number = float(input('Enter a positive number (negative to quit): '))
#
#     if number > 0
#         total = total + number
#     else:  #if negative number is detected or zero break for loop and print results
#         break
# #print results with 2 decimal places as float value
# print (f'Total = {total:.2f}')

# %%
# Add comments to the program
# static value for calories per minute burned
caloriesPerMinute = 4.2

#declare default values, set to zero
caloriesBurned = 0.0
minutes = 0

#output Prompts for a chart header
print ('Minutes\t\tCalories Burned')
print ('-------------------------------')

#create chart with columns for 10-31mins of workout
#use range as a guide( start, end, count by 5's) 
#perform calculations and out put with double tabs
for minutes in range(10, 31, 5):
    caloriesBurned = caloriesPerMinute * minutes
    print (minutes, "\t\t", caloriesBurned)

# %% [markdown]
# After running this program, think about and answer these questions:
#
# 1. What is the program doing?
#
# program builds a chart with headers and outputs results in two columns
# 2. How many time does each line in the code execute, explain?
#
# in the for loop, starting at int(10), a count incrementing 5 units as minutes, to the number 31.
# each line, in the for loop is run 5 times.
# 3. Could you find a way to break it?
# 4. Try to rewrite the program using a while loop.
# caloriesPerMinute = 4.2
# caloriesBurned= 0.0
# minutes = 10
#
# print ('Minutes\t\tCalories Burned')
# print ('-------------------------------')
# while minutes < 31:
#     caloriesBurned = caloriesPerMinute * minutes
#     print(minutes, "\t\t", caloriesBurned)
#     minutes += minutes + 5

# %%
# Add comments to the program 

totalRainfall = 0.0
monthRainfall = 0.0
averageRainfall = 0.0
years = 0
totalMonths = 0

#get user input for years to calculate
years = int(input('Enter the number of years: '))

#peform 
for year in range(years):
    print (f'For year {year + 1}:')
    for month in range(12):
        monthRainfall = float(input('Enter the rainfall amount for the month: '))
        totalMonths += 1
        totalRainfall += monthRainfall
        
averageRainfall = totalRainfall / totalMonths

print(f'For {totalMonths} months')
print(f'Total rainfall: {totalRainfall:,.2f} inches')
print(f'Average monthly rainfall: {averageRainfall:,.2f} inches')
# Out:
# Enter the number of years:  2
# For year 1:
# Enter the rainfall amount for the month:  2.0
# Enter the rainfall amount for the month:  1.0
# Enter the rainfall amount for the month:  0
# Enter the rainfall amount for the month:  0
# Enter the rainfall amount for the month:  0
# Enter the rainfall amount for the month:  0
# Enter the rainfall amount for the month:  3.2
# Enter the rainfall amount for the month:  2.4
# Enter the rainfall amount for the month:  3.0
# Enter the rainfall amount for the month:  1.5
# Enter the rainfall amount for the month:  1.2
# Enter the rainfall amount for the month:  1
# For year 2:
# Enter the rainfall amount for the month:  2.0
# Enter the rainfall amount for the month:  0
# Enter the rainfall amount for the month:  0
# Enter the rainfall amount for the month:  0
# Enter the rainfall amount for the month:  1.1
# Enter the rainfall amount for the month:  1.2
# Enter the rainfall amount for the month:  1.1
# Enter the rainfall amount for the month:  1.0
# Enter the rainfall amount for the month:  0
# Enter the rainfall amount for the month:  0
# Enter the rainfall amount for the month:  0
# Enter the rainfall amount for the month:  0
# For 24 months
# Total rainfall: 21.70 inches
# Average monthly rainfall: 0.90 inches

# %% [markdown]
# After running this program, think about and answer these questions:
#
# 1. What is the program doing?
#
# the Program calculates average rainfall per the number of years defined by user input,
# and its monthly average over the user defined 'year interval.'
# 2. How many time does each line in the code execute, explain?
#
# the nested "for loops" cycle through the number of years supplied by user input,
# per each year, the lines of code execute 12 times (for months in the year).
# 3. Could you find a way to break it?
#
# enter a character, symbol will break the code.
# 4. Compare the number of executuions for the inner for loop to the outer for loop.
#
# 12 times the inner loop will execute, and the outer only 0 to user defined int(input).
# 5. What order of magnitude larger are the inner instructions executing?
#
# 12x

# %% [markdown]
# ## 1.3 Basic loop structures (Group):
#
# Develop a program that will:
#
# 1. Take input from the user asking how many organisms to start with.
# 2. Take input from the user asking the average daily increase for the organisms.
# 3. Take input from the user asking the number of days to multiply.
# 4. Make sure the daily increase was entered as a percentage, if not correct it.
# 5. Print each day and the increase in organsisms for each day.
# 6. Make sure to format the printing so that it is readable.

# %%
"""
Created on Tue Jan 11 08:24:27 2022

@author: skciller

## 1.3 Basic loop structures (Group):

Develop a program that will:

1. Take input from the user asking how many organisms to start with.
2. Take input from the user asking the average daily increase for the organisms.
3. Take input from the user asking the number of days to multiply.
4. Make sure the daily increase was entered as a percentage, if not correct it.
5. Print each day and the increase in organsisms for each day. 
6. Make sure to format the printing so that it is readable.
"""
#instruction 1
organisms = int(input("how many organism: "))


while True:
    try:
        # instruction 2
        percentinput = input("daily growth percentage: ")
        # instruction 4
        if percentinput.__contains__("%"):
            break
        else:
            print(".. please enter a % after int")
    except:
        print(".. please enter a % after int")

# instruction 3
num_days = int(input("how many days to calculate: "))
total_org = org_growth = 0

print("Organisms 		@",percentinput," Daily Growth")
print("-------------------------------")

#strip the percent character and 
#convert to actual percentage
percentgrowth = int(percentinput.strip("%"))/100

#instruction 6 
for days in range(num_days):
    org_growth = float(organisms + (organisms * percentgrowth)* days)
    # instruction 5
    print("Day: ", days, "\t\t", org_growth)
# Out:
# how many organism: 100
# daily growth percentage: 40%
# how many days to calculate: 5
# Organisms 		@ 40%  Daily Growth
# -------------------------------
# Day:  0 		 100.0
# Day:  1 		 140.0
# Day:  2 		 180.0
# Day:  3 		 220.0
# Day:  4 		 260.0

# %% [markdown]
# ## 1.4 Data Structures (Follow):
#
# **Learning Objectives:**
#
#     1. Understand list and tuples
#     2. Understand dictionaries and sets
#     3. Understand strings

# %%
# Add comments to the program

total_sales = 0.0

daily_sales_tuple = (7.0, 5.0, 3.2, 1.7, 6.0, 4.9, 1.1) 
daily_sales_list = [7.0, 5.0, 3.2, 1.7, 6.0, 4.9, 1.1]

days_of_week = ['Sunday', 'Monday', 'Tuesday',
                    'Wednesday', 'Thursday', 'Friday',
                    'Saturday']

for number in daily_sales_list:
        total_sales += number

print (f'Total sales for the week: ${total_sales:,.2f}')

total_sales = 0.0
for number in daily_sales_tuple:
        total_sales += number

print (f'Total sales for the week: ${total_sales:,.2f}')


print (f'Sales per day: ')
for i in range(7):
        print(f"{days_of_week[i] : <10}", f"{daily_sales_list[i] : >20}")
        print(f"{days_of_week[i] : <10}", f"{daily_sales_tuple[i] : >20}")
        
daily_sales_list[5] = 10.0 
#daily_sales_tuple[5] = 10.0  #uncomment this line to see what happens

new_value = 3.2
daily_sales_list.append(new_value)
new_daily_sales_tuple = daily_sales_tuple + (new_value,)
# new_value, is syntax correct entry

days_of_week.append('Sunday')

print("")
print (f'Sales per day: ')
for i in range(len(days_of_week)):
        print(f"{days_of_week[i] : <10}", f"{daily_sales_list[i] : >20}")
        print(f"{days_of_week[i] : <10}", f"{new_daily_sales_tuple[i] : >20}")

# %% [markdown]
# After running the above code, think about and answer the following questions:
#
# 1. What is the program doing?
# 2. What does the append function do?
# 3. Which actual entry is changed when setting daily sales[5] to 10?
# 4. Discuss and the similarities and differences between lists and tuples.

# %%
# Add comments to the program

import random
#dictionary

capitals = {'Alabama':'Montgomery', 'Alaska':'Juneau',
                'Arizona':'Phoenix', 'Arkansas':'Little Rock',
                'California':'Sacramento', 'Colorado':'Denver',
                'Connecticut':'Hartford', 'Delaware':'Dover',
                'Florida':'Tallahassee', 'Georgia':'Atlanta',
                'Hawaii':'Honolulu', 'Idaho':'Boise',
                'Illinois':'Springfield', 'Indiana':'Indianapolis',
                'Iowa':'Des Moines', 'Kansas':'Topeka',
                'Kentucky':'Frankfort', 'Louisiana':'Baton Rouge',
                'Maine':'Augusta', 'Maryland':'Annapolis',
                'Massachusetts':'Boston', 'Michigan':'Lansing',
                'Minnesota':'Saint Paul', 'Mississippi':'Jackson',
                'Missouri':'Jefferson City', 'Montana':'Helena',
                'Nebraska':'Lincoln', 'Nevada':'Carson City',
                'New Hampshire':'Concord', 'New Jersey':'Trenton',
                'New Mexico':'Santa Fe', 'New York':'Albany',
                'North Carolina':'Raleigh', 'North Dakota':'Bismarck',
                'Ohio':'Columbus', 'Oklahoma':'Oklahoma City',
                'Oregon':'Salem', 'Pennsylvania':'Harrisburg',
                'Rhode Island':'Providence', 'South Carolina':'Columbia',
                'South Dakota':'Pierre', 'Tennessee':'Nashville',
                'Texas':'Austin', 'Utah':'Salt Lake City',
                'Vermont':'Montpelier', 'Virginia':'Richmond',
                'Washington':'Olympia', 'West Virginia':'Charleston',
                'Wisconsin':'Madison', 'Wyoming':'Cheyenne'}
                
correct = 0
wrong = 0
next_question = True
index = 0
user_solution = ''


while next_question:

    state_iterator = iter(capitals)
        
    index = (random.randint(1,50) - 1)
    for i in range (index-1):
        temp = state_iterator.__next__()
    current_state = str(state_iterator.__next__())

    user_solution = input(f'What is the capital of {current_state}? 'f'(or enter 0 to quit): ')
        
    if user_solution == '0': 
        next_question = False
        print(f'You had {correct} correct responses and 'f'{wrong} incorrect responses.')  
        
    elif user_solution == capitals[current_state]:
        correct = correct + 1
        print('That is correct.')
        
    else:
        wrong = wrong + 1
        print('That is incorrect.')

# %% [markdown]
# After running the above code, think about and answer the following questions:
#
# 1. What is the program doing?
# 2. What does a key in a dictionary do? What does the value in a dictionary do?
# 3. Where would you be more likely to use a dictionary versus using a list or tuple?
# 4. How are dictionaries different from tuples and lists?

# %%
# add comments to the program

baseball = set(['Jodi', 'Carmen', 'Aida', 'Alicia'])
basketball = set(['Eva', 'Carmen', 'Alicia', 'Sarah'])

print('The following students are on the baseball team:')
for name in baseball:
    print(name)

print()
print('The following students are on the basketball team:')
for name in basketball:
    print(name)

print()
print('The following students play both baseball and basketball:')
for name in baseball.intersection(basketball):
    print(name)

print()
print('The following students play either baseball or basketball:')
for name in baseball.union(basketball):
    print(name)

print()
print('The following students play baseball, but not basketball:')
for name in baseball.difference(basketball):
    print(name)

print()
print('The following students play basketball, but not baseball:')
for name in basketball.difference(baseball):
    print(name)

print()
print('The following students play one sport, but not both:')
for name in baseball.symmetric_difference(basketball):
    print(name)

# %% [markdown]
# After running the above code, think about and answer the following questions:
#
# 1. What is the program doing?
# 2. What does a set do and how is it used above?
# 3. Where would you be more likely to use a set versus using a dictionary, list, or tuple?
# 4. How are sets different from dictionaries, tuples, and lists?

# %% [markdown]
# ## 1.4 Data Structures (Group):
#
# Create a program that does the following:
#
# 1. Take the two lists provided and count the frequency of each word in each list.
# 2. Create a dictionary with the key equal to each unique word and count as the value.
# 3. Print off a list of words that are in both lists.
# 4. Print off a list of words that are in the first list and not the second.
# 5. Print off a list of words that are in the second list and not in the first.

# %%
def histogram(s,show=0):
    d = dict()
    for c in s: 
        if c not in d: 
            d[c] = 1 #if none found -default to 1
        else:
            d[c] += 1 #count unique words if found
    if show == 0:
        print(d) #prints output of histogram
    return d

list1 = ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
list2 = ['jack', 'be', 'nimble', 'jack', 'be', 'quick', 'jack', 'jumps', 'over', 'the', 'candlestick']
#instruction 1
#cleaned up the code and just wrote a function histogram(list, print results or not)
counts = dict()
histogram(list1) # use the function to count words for list1
histogram(list2) # use the function to count words for list2
#instruction 2 
counts = histogram(list1 + list2,1)  #opted to not show (print output))

set1 = set(list1)
set2 = set(list2)

#instruction 3, 4, 5 
print(set1.intersection(set2))
print(set1.difference(set2))
print(set2.difference(set1))

del counts ;
# Out:
# {'the': 2, 'quick': 1, 'brown': 1, 'fox': 1, 'jumps': 1, 'over': 1, 'lazy': 1, 'dog': 1}
# {'jack': 3, 'be': 2, 'nimble': 1, 'quick': 1, 'jumps': 1, 'over': 1, 'the': 1, 'candlestick': 1}
# {'quick', 'over', 'jumps', 'the'}
# {'fox', 'brown', 'lazy', 'dog'}
# {'be', 'candlestick', 'nimble', 'jack'}
