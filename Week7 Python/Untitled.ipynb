# %%
import pandas as pd

df = pd.DataFrame(

    {"AAA": [4, 5, 6, 7], "BBB": [10, 20, 30, 40], "CCC": [100, 50, -30, -50]}

)

df
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Thu Feb 24 15:25:39 2022

@author: skciller
"""
import pandas as pd

def Athletes(self, name, sex, age, height, weight, team, NOC, games, year, season, city, sport, event, medal):
    
    def __init__(self):
        self.__name = name
        self.__sex = sex
        self.__age = age
        self.__height = height
        self.__weight = weight
        self.__team = team
        self.__NOC = NOC
        self.__games = games
        self.__year =  year
        self.__season = season
        self.__sport = sport
        self.__event = event
        self.__medal = medal
        
    def get_age(self):
        try:
            if int(self.__age) > 0:
                return int(self.__age)
        except:
            pass
            return 0
                
    def get_weight(self):
        try:
            if int(self.__weight) > 0:
                return int(self.__weight)
        except:
            pass
            return 0
        
    def get_height(self):
        try:
            if int(self.__height) > 0:
                return int(self.__height)
        except:
            pass
            return 0

    def get_all(self):
        return 'self.__name,self.__sex,self.__age,' \
                'self.__height,self.__weight,self.__team,self.__NOC,self.__games,' \
                'self.__year, self.__season, self.__sport, self.__event, self.__medal'



df = pd.read_csv('../Week7 Python/athlete_events_short.csv', skiprows=0, index_col=0)
reader = df.head()

    ## multiple ways to read columns
#print(df.head(0))
#print(reader.columns)

    ##print all to output
#print(reader)

    ##read data single line
#print(df.head(1))

    ##print a column
#print(df['Name'])
#print multiple columns  
#print(df[['Name','Height','Weight','Medal']])

    ##print a row      #iterate through rows using df
#print(df.iloc[1])     # for index, row in df.iterrows():
#print(df.iloc[4:6])   #    print(index,row['Name'])

    #print a specific value
#print(df.iloc[4:6,0])

    ##list only variables of your choosing
#print(df.loc[df['Event']== "Speed Skating Women's 500 metres"])

    ## using describe to get stats
#print(df.describe())

    ## sort values by name
# df.sort_values('Name') 
# or df.sort_values('Name', ascending=True)
# or df.sort_values('Name', ascending=False)
# or by multiple rows 
    #print(df.sort_values(['Age','Name', 'Games']))
# sort first row ascending, and second decending
    #df.sort_values(['Age','Name', 'Games'], ascending=[1,0,0]).head(5))
# sort first row ascending, and second decending and print out the first 5 rows
#df.sort_values(['Age','Name', 'Games', 'Year'], ascending=[1,0,0,0]).head(5)


#save to csv, or excel 
    #df.to_csv('modified', index=False)  #save without index row
    #df.to_csv('modified', index=False, sep='\t')  #save without index row
    #df.to_excel('modified', index=False)  #save without index row
    
### FILTER DATA ###
    # by two column variables
    #example: df.loc[ () & () ]
    #search with starts with #df[df.index.str.startswith('h', na=False)]
new_df = df.loc[(df['Season'] == "Summer") & (df['Year'] == 2008) & (df['Event'].str.startswith('A', na=False))]

    #search with ENDS WITH 
    #df[df.index.str.endswith('k', na=False)]

## remove index of our output
#Ex: new_df = df.loc[(df['Season'] == "Summer") & (df['Year'] == 2008) & (df['Event'].str.startswith('A', na=False))]
# new_df .reset_index(drop = true, inplace=True) or
## new_df = new_df.reset_index(drop=True)
new_df
# Out:
#                                         Name Sex   Age  Height  Weight  \
# ID
# 49                              Moonika Aava   F  28.0   168.0    65.0
# 67   Mariya Vasilyevna Abakumova (-Tarabina)   F  22.0   179.0    80.0
# 129                           Ruslan Abbasov   M  22.0   181.0    74.0
# 154                          Khadija Abbouda   F  40.0   165.0    57.0
# 160                      Ali Abdalla Afringi   M  25.0   163.0    57.0
# 234             Abdalla Abdelgadir El-Sheikh   M  21.0   170.0    58.0
# 252                              Youcef Abdi   M  30.0   178.0    66.0
# 256              Abdihakim "Abdi" Abdirahman   M  31.0   178.0    61.0
# 299              Dana Abdul Razak (Hussain-)   F  22.0   163.0    56.0
# 314                  Rukayatu "Ruky" Abdulai   F  22.0   180.0    59.0
# 321                    Ahmad Hassan Abdullah   M  27.0   164.0    55.0
# 382                          Soha Abed Elaal   F  35.0     NaN     NaN
# 402                             Arthur Abele   M  22.0   184.0    85.0
# 428                        Elvan Abeylegesse   F  25.0   159.0    40.0
# 428                        Elvan Abeylegesse   F  25.0   159.0    40.0
# 440                          Mitsuhiro Abiko   M  19.0   169.0    62.0
# 449                  Inga Eduardovna Abitova   F  26.0   164.0    58.0
# 488              Ibrahim Mohamedin Aboubaker   M  25.0   190.0    65.0
# 541               Andrey Viktorovich Abramov   M  24.0   176.0    70.0
# 541               Andrey Viktorovich Abramov   M  24.0   176.0    70.0
# 556               Arnaldo Lus Isaas Abrantes   M  21.0   183.0    72.0
#
#               Team  NOC        Games  Year  Season     City      Sport  \
# ID
# 49         Estonia  EST  2008 Summer  2008  Summer  Beijing  Athletics
# 67          Russia  RUS  2008 Summer  2008  Summer  Beijing  Athletics
# 129     Azerbaijan  AZE  2008 Summer  2008  Summer  Beijing  Athletics
# 154        Morocco  MAR  2008 Summer  2008  Summer  Beijing    Archery
# 160        Eritrea  ERI  2008 Summer  2008  Summer  Beijing  Athletics
# 234          Sudan  SUD  2008 Summer  2008  Summer  Beijing  Athletics
# 252      Australia  AUS  2008 Summer  2008  Summer  Beijing  Athletics
# 256  United States  USA  2008 Summer  2008  Summer  Beijing  Athletics
# 299           Iraq  IRQ  2008 Summer  2008  Summer  Beijing  Athletics
# 314         Canada  CAN  2008 Summer  2008  Summer  Beijing  Athletics
# 321          Qatar  QAT  2008 Summer  2008  Summer  Beijing  Athletics
# 382          Egypt  EGY  2008 Summer  2008  Summer  Beijing    Archery
# 402        Germany  GER  2008 Summer  2008  Summer  Beijing  Athletics
# 428         Turkey  TUR  2008 Summer  2008  Summer  Beijing  Athletics
# 428         Turkey  TUR  2008 Summer  2008  Summer  Beijing  Athletics
# 440          Japan  JPN  2008 Summer  2008  Summer  Beijing  Athletics
# 449         Russia  RUS  2008 Summer  2008  Summer  Beijing  Athletics
# 488          Qatar  QAT  2008 Summer  2008  Summer  Beijing  Athletics
# 541         Russia  RUS  2008 Summer  2008  Summer  Beijing    Archery
# 541         Russia  RUS  2008 Summer  2008  Summer  Beijing    Archery
# 556       Portugal  POR  2008 Summer  2008  Summer  Beijing  Athletics
#
#                                          Event   Medal
# ID
# 49             Athletics Women's Javelin Throw     NaN
# 67             Athletics Women's Javelin Throw  Silver
# 129                 Athletics Men's 100 metres     NaN
# 154                 Archery Women's Individual     NaN
# 160               Athletics Men's 5,000 metres     NaN
# 234               Athletics Men's 1,500 metres     NaN
# 252  Athletics Men's 3,000 metres Steeplechase     NaN
# 256              Athletics Men's 10,000 metres     NaN
# 299               Athletics Women's 100 metres     NaN
# 314                Athletics Women's Long Jump     NaN
# 321              Athletics Men's 10,000 metres     NaN
# 382                 Archery Women's Individual     NaN
# 402                  Athletics Men's Decathlon     NaN
# 428             Athletics Women's 5,000 metres  Silver
# 428            Athletics Women's 10,000 metres     NaN
# 440       Athletics Men's 4 x 400 metres Relay     NaN
# 449            Athletics Women's 10,000 metres     NaN
# 488                Athletics Men's Triple Jump     NaN
# 541                   Archery Men's Individual     NaN
# 541                         Archery Men's Team     NaN
# 556                 Athletics Men's 200 metres     NaN
